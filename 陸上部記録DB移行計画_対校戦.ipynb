# %%
import pandas as pd
import numpy as np
import re
import math
import copy

# %%
html = 'schedule/s2016/index.php'
fetched_dataframes = pd.io.html.read_html(html)
name = html.split('/')[1] + '_' + html.split('/')[2].split('.')[0]

# %%
j = 5
fetched_dataframes[j]
# Out:
#                                0                      1        2  \
# 0                             種目                     選手       記録
# 1                           100m                  天野　皓平     10"8
# 2                          岩井　梨輝                   10"9       2着
# 3                           200m                  天野　皓平     22"3
# 4                          西嶋　健人                   22"5       3着
# 5                           400m                  高橋　知也     50"2
# 6                          中嶋　一貴                   51"3       3着
# 7                           800m                  箱崎　喜郎   1'59"9
# 8                          井上　暁人                 2'00"3       2着
# 9                          1500m                   塩田　匠   4'02"9
# 10                         箱崎　喜郎                 4'03"6       3着
# 11                         5000m                   塩田　匠  15'14"3
# 12                        新美　惣一朗                15'36"9       2着
# 13                         110mH                  永島　唯哉     14"7
# 14                         400mH                  永島　唯哉     56"2
# 15                       4×100mR    天野　皓平西嶋　健人永井　生永島　唯哉     41"5
# 16                       4×400mR   高橋　知也中嶋　一貴中村　勇太芝江　柾葵   3'26"9
# 17                           走高跳                  小河　雅広     1m40
# 18                           走幅跳                  石井　裕太     6m30
# 19                          櫛田　優                   5m96       3等
# 20                           砲丸投                  福井　義光     8m34
# 21                         久保　謙太                   7m79       4等
# 22                       100m OP                  米川　晴義     11"2
# 23                         中村　彩人                   11"6     2組2着
# 24                         下山　達大                   11"8     2組4着
# 25                         白井　陸大                   12"1     2組5着
# 26                       200m OP                   永井　生     23"4
# 27                         米川　晴義                   23"7       2着
# 28                         野村　勝洋                   24"6       3着
# 29                         木原　葉子                   27"1       6着
# ..                           ...                    ...      ...
# 54                         山内　岳秋                16'38"2       4着
# 55                         杉浦　拓馬                16'45"1       5着
# 56                         小林　雅彦                17'04"0       7着
# 57                          笠原　慧                17'14"1       9着
# 58                        田井　裕次郎                17'50"3      13着
# 59                         河合　正貴                    DNS        -
# 60                         丸山　蒼太                    DNS        -
# 61                    4×100mR OP    中村　勇太尾川　拓巳前田　颯下山　達大     45"7
# 62          足立　茉優富田　彩花鳥山　夏海木原　葉子                   55"6       2着
# 63                    4×400mR OP  佐々木　亮一土田　周治井上　暁人細川　和穂   3'41"2
# 64         新美　惣一朗箱崎　喜郎山内　岳秋杉浦　拓馬                 3'53"8     1組2着
# 65          岩井　梨輝片瀬　悠喜益田　一毅中村　勇太                 3'57"6     1組3着
# 66          宮田　貴史米川　晴義松井　将器細川　和穂                 3'46"6     2組2着
# 67           森　達也中野　佑太天野　皓平久保　謙太                 3'49"0     2組3着
# 68   永島　唯哉尾川　拓巳中村　彩人福井　義光・上田　菜々子                 3'57"8     2組4着
# 69         吉田　啓一郎久司　駿三赤塚　洋介土田　周治                 4'25"2     2組4着
# 70          小林　裕平笠木　浩平野村　勝洋細川　和穂                 3'49"7     3組1着
# 71           笠原　慧柴田　幸樹小林　雅彦永瀬　翔平                 4'00"2     3組2着
# 72           岩井　梨輝永井　生片瀬　悠喜白井　陸大                 4'02"4     3組3着
# 73  井上　暁人田井　裕次郎上田　菜々子・五日市　実侑塩田　匠                 4'11"9     3組5着
# 74           前田　颯赤塚　洋介福井　義光土田　周治                 4'57"3     3組6着
# 75                        走高跳 OP                  足達　哲也     1m65
# 76                         永瀬　翔平                   1m25       6等
# 77                        走幅跳 OP                  永瀬　翔平     5m42
# 78                         鳥山　夏海                   4m90       3等
# 79                         赤塚　洋介                   4m08       4等
# 80                        砲丸投 OP                  土田　周治     8m36
# 81                         白井　陸大                   6m68       5等
# 82                         野村　勝洋                   6m40       8等
# 83                         片瀬　悠喜                   6m28       9等
#
#                          3                    4
# 0                       着順                 風･備考
# 1                       1着                 +2.4
# 2                     +2.4                  NaN
# 3                       1着                 -2.4
# 4          -2.4/PB/歴代14位タイ                  NaN
# 5                       2着                    -
# 6               PB/歴代27位タイ                  NaN
# 7                       1着                    -
# 8                        -                  NaN
# 9                       1着                    -
# 10                PB/歴代16位                  NaN
# 11                      1着                    -
# 12                       -                  NaN
# 13                      1着                 +2.2
# 14                      1着              PB/歴代5位
# 15                      1着                工大新記録
# 16                      1着                    -
# 17                      3等                    -
# 18                      1等  +3.8/PB(6m17(+1.3))
# 19                    +3.6                  NaN
# 20                      2等                    -
# 21                       -                  NaN
# 22                    1組2着                 +1.6
# 23                    +2.3                  NaN
# 24                    +2.3                  NaN
# 25                    +2.3                  NaN
# 26                      1着                 -4.2
# 27                    -4.2                  NaN
# 28                    -4.2                  NaN
# 29              -4.2/工大新記録                  NaN
# ..                     ...                  ...
# 54                     NaN                  NaN
# 55                       -                  NaN
# 56                       -                  NaN
# 57                       -                  NaN
# 58                       -                  NaN
# 59                       -                  NaN
# 60                       -                  NaN
# 61                      1着                    -
# 62                       -                  NaN
# 63                    1組1着                    -
# 64                       -                  NaN
# 65                       -                  NaN
# 66                       -                  NaN
# 67                       -                  NaN
# 68                       -                  NaN
# 69                       -                  NaN
# 70                       -                  NaN
# 71                       -                  NaN
# 72                       -                  NaN
# 73                       -                  NaN
# 74                       -                  NaN
# 75                      1等                    -
# 76                       -                  NaN
# 77                      2等                 +2.4
# 78  +2.9/工大新記録(4m79(+1.7))                  NaN
# 79                    +1.1                  NaN
# 80                      2等                    -
# 81                       -                  NaN
# 82                       -                  NaN
# 83                       -                  NaN
#
# [84 rows x 5 columns]

# %%
k = 12
fetched_dataframes[k]
# Out:
#          0        1        2    3    4
# 0       種目       選手       記録   着順   備考
# 1     20km    松井　将器  1:00'58  52位    -
# 2    丸山　蒼太  1:09'32     459位    -  NaN
# 3    小林　裕平  1:10'31     495位    -  NaN
# 4    武田　直樹  1:11'35     519位    初  NaN
# 5    萩原　健太  1:11'54     531位    初  NaN
# 6    笠木　浩平  1:12'02     538位    -  NaN
# 7   田野倉　佑介  1:12'45     551位    -  NaN
# 8     辻　航平  1:13'50     562位    -  NaN
# 9   外山　真矢人  1:16'22     578位    -  NaN
# 10   山根　圭太  1:17'27     581位    -  NaN

# %%
dfs = pd.concat([fetched_dataframes[i].iloc[1:, :] for i in range(j, k+1)])
dfs
# Out:
#                0                     1        2                3  \
# 1           100m                 天野　皓平     10"8               1着
# 2          岩井　梨輝                  10"9       2着             +2.4
# 3           200m                 天野　皓平     22"3               1着
# 4          西嶋　健人                  22"5       3着  -2.4/PB/歴代14位タイ
# 5           400m                 高橋　知也     50"2               2着
# 6          中嶋　一貴                  51"3       3着       PB/歴代27位タイ
# 7           800m                 箱崎　喜郎   1'59"9               1着
# 8          井上　暁人                2'00"3       2着                -
# 9          1500m                  塩田　匠   4'02"9               1着
# 10         箱崎　喜郎                4'03"6       3着         PB/歴代16位
# 11         5000m                  塩田　匠  15'14"3               1着
# 12        新美　惣一朗               15'36"9       2着                -
# 13         110mH                 永島　唯哉     14"7               1着
# 14         400mH                 永島　唯哉     56"2               1着
# 15       4×100mR   天野　皓平西嶋　健人永井　生永島　唯哉     41"5               1着
# 16       4×400mR  高橋　知也中嶋　一貴中村　勇太芝江　柾葵   3'26"9               1着
# 17           走高跳                 小河　雅広     1m40               3等
# 18           走幅跳                 石井　裕太     6m30               1等
# 19          櫛田　優                  5m96       3等             +3.6
# 20           砲丸投                 福井　義光     8m34               2等
# 21         久保　謙太                  7m79       4等                -
# 22       100m OP                 米川　晴義     11"2             1組2着
# 23         中村　彩人                  11"6     2組2着             +2.3
# 24         下山　達大                  11"8     2組4着             +2.3
# 25         白井　陸大                  12"1     2組5着             +2.3
# 26       200m OP                  永井　生     23"4               1着
# 27         米川　晴義                  23"7       2着             -4.2
# 28         野村　勝洋                  24"6       3着             -4.2
# 29         木原　葉子                  27"1       6着       -4.2/工大新記録
# 30       400m OP                 中村　勇太     51"9               1着
# ..           ...                   ...      ...              ...
# 124  女子七種競技100mH                     1    鳥山　夏海              DNS
# 125   女子七種競技200m                     1    鳥山　夏海              DNS
# 126    女子七種競技走高跳                     1    鳥山　夏海              DNS
# 127    女子七種競技砲丸投                     1    鳥山　夏海              DNS
# 128   女子七種競技800m                     1    鳥山　夏海              DNS
# 129    女子七種競技走幅跳                     1    鳥山　夏海              DNS
# 130    女子七種競技やり投                     1    鳥山　夏海              DNS
# 131       女子七種競技                     1    鳥山　夏海              DNS
# 1           20km                  塩田　匠  1:03'43             227位
# 2          多田　駿介               1:07'29     390位          初/歴代18位
# 3          杉浦　拓馬               1:08'34     429位         PB/歴代26位
# 4          箱崎　喜郎               1:09'15     454位         PB/歴代39位
# 5          井上　暁人               1:09'26     458位         PB/歴代40位
# 6          山内　岳秋               1:10'04     482位                -
# 7          奈良　悠冬               1:10'47     502位               PB
# 8          久司　駿三               1:11'47     528位                初
# 9          江頭　悠郎               1:12'08     540位               PB
# 10          阿川　陽               1:12'16     541位                初
# 11         小島　俊平               1:15'46     575位                -
# 12        田井　裕次郎                    DQ        -                -
# 1           20km                 松井　将器  1:00'58              52位
# 2          丸山　蒼太               1:09'32     459位                -
# 3          小林　裕平               1:10'31     495位                -
# 4          武田　直樹               1:11'35     519位                初
# 5          萩原　健太               1:11'54     531位                初
# 6          笠木　浩平               1:12'02     538位                -
# 7         田野倉　佑介               1:12'45     551位                -
# 8           辻　航平               1:13'50     562位                -
# 9         外山　真矢人               1:16'22     578位                -
# 10         山根　圭太               1:17'27     581位                -
#
#                        4    5
# 1                   +2.4  NaN
# 2                    NaN  NaN
# 3                   -2.4  NaN
# 4                    NaN  NaN
# 5                      -  NaN
# 6                    NaN  NaN
# 7                      -  NaN
# 8                    NaN  NaN
# 9                      -  NaN
# 10                   NaN  NaN
# 11                     -  NaN
# 12                   NaN  NaN
# 13                  +2.2  NaN
# 14               PB/歴代5位  NaN
# 15                 工大新記録  NaN
# 16                     -  NaN
# 17                     -  NaN
# 18   +3.8/PB(6m17(+1.3))  NaN
# 19                   NaN  NaN
# 20                     -  NaN
# 21                   NaN  NaN
# 22                  +1.6  NaN
# 23                   NaN  NaN
# 24                   NaN  NaN
# 25                   NaN  NaN
# 26                  -4.2  NaN
# 27                   NaN  NaN
# 28                   NaN  NaN
# 29                   NaN  NaN
# 30            PB/歴代35位タイ  NaN
# ..                   ...  ...
# 124                    -    -
# 125                    -    -
# 126                    -    -
# 127                    -    -
# 128                    -    -
# 129                    -    -
# 130                    -    -
# 131                    -    -
# 1                PB/歴代4位  NaN
# 2                    NaN  NaN
# 3                    NaN  NaN
# 4                    NaN  NaN
# 5                    NaN  NaN
# 6                    NaN  NaN
# 7                    NaN  NaN
# 8                    NaN  NaN
# 9                    NaN  NaN
# 10                   NaN  NaN
# 11                   NaN  NaN
# 12                   NaN  NaN
# 1                      -  NaN
# 2                    NaN  NaN
# 3                    NaN  NaN
# 4                    NaN  NaN
# 5                    NaN  NaN
# 6                    NaN  NaN
# 7                    NaN  NaN
# 8                    NaN  NaN
# 9                    NaN  NaN
# 10                   NaN  NaN
#
# [524 rows x 6 columns]

# %%
dfs.columns=['種目', '組', '選手', '記録', '着順', '風・備考']
dfs = dfs.reset_index(drop=True)

dfs
# Out:
#               種目                     組       選手               記録  \
# 0           100m                 天野　皓平     10"8               1着
# 1          岩井　梨輝                  10"9       2着             +2.4
# 2           200m                 天野　皓平     22"3               1着
# 3          西嶋　健人                  22"5       3着  -2.4/PB/歴代14位タイ
# 4           400m                 高橋　知也     50"2               2着
# 5          中嶋　一貴                  51"3       3着       PB/歴代27位タイ
# 6           800m                 箱崎　喜郎   1'59"9               1着
# 7          井上　暁人                2'00"3       2着                -
# 8          1500m                  塩田　匠   4'02"9               1着
# 9          箱崎　喜郎                4'03"6       3着         PB/歴代16位
# 10         5000m                  塩田　匠  15'14"3               1着
# 11        新美　惣一朗               15'36"9       2着                -
# 12         110mH                 永島　唯哉     14"7               1着
# 13         400mH                 永島　唯哉     56"2               1着
# 14       4×100mR   天野　皓平西嶋　健人永井　生永島　唯哉     41"5               1着
# 15       4×400mR  高橋　知也中嶋　一貴中村　勇太芝江　柾葵   3'26"9               1着
# 16           走高跳                 小河　雅広     1m40               3等
# 17           走幅跳                 石井　裕太     6m30               1等
# 18          櫛田　優                  5m96       3等             +3.6
# 19           砲丸投                 福井　義光     8m34               2等
# 20         久保　謙太                  7m79       4等                -
# 21       100m OP                 米川　晴義     11"2             1組2着
# 22         中村　彩人                  11"6     2組2着             +2.3
# 23         下山　達大                  11"8     2組4着             +2.3
# 24         白井　陸大                  12"1     2組5着             +2.3
# 25       200m OP                  永井　生     23"4               1着
# 26         米川　晴義                  23"7       2着             -4.2
# 27         野村　勝洋                  24"6       3着             -4.2
# 28         木原　葉子                  27"1       6着       -4.2/工大新記録
# 29       400m OP                 中村　勇太     51"9               1着
# ..           ...                   ...      ...              ...
# 494  女子七種競技100mH                     1    鳥山　夏海              DNS
# 495   女子七種競技200m                     1    鳥山　夏海              DNS
# 496    女子七種競技走高跳                     1    鳥山　夏海              DNS
# 497    女子七種競技砲丸投                     1    鳥山　夏海              DNS
# 498   女子七種競技800m                     1    鳥山　夏海              DNS
# 499    女子七種競技走幅跳                     1    鳥山　夏海              DNS
# 500    女子七種競技やり投                     1    鳥山　夏海              DNS
# 501       女子七種競技                     1    鳥山　夏海              DNS
# 502         20km                  塩田　匠  1:03'43             227位
# 503        多田　駿介               1:07'29     390位          初/歴代18位
# 504        杉浦　拓馬               1:08'34     429位         PB/歴代26位
# 505        箱崎　喜郎               1:09'15     454位         PB/歴代39位
# 506        井上　暁人               1:09'26     458位         PB/歴代40位
# 507        山内　岳秋               1:10'04     482位                -
# 508        奈良　悠冬               1:10'47     502位               PB
# 509        久司　駿三               1:11'47     528位                初
# 510        江頭　悠郎               1:12'08     540位               PB
# 511         阿川　陽               1:12'16     541位                初
# 512        小島　俊平               1:15'46     575位                -
# 513       田井　裕次郎                    DQ        -                -
# 514         20km                 松井　将器  1:00'58              52位
# 515        丸山　蒼太               1:09'32     459位                -
# 516        小林　裕平               1:10'31     495位                -
# 517        武田　直樹               1:11'35     519位                初
# 518        萩原　健太               1:11'54     531位                初
# 519        笠木　浩平               1:12'02     538位                -
# 520       田野倉　佑介               1:12'45     551位                -
# 521         辻　航平               1:13'50     562位                -
# 522       外山　真矢人               1:16'22     578位                -
# 523        山根　圭太               1:17'27     581位                -
#
#                       着順 風・備考
# 0                   +2.4  NaN
# 1                    NaN  NaN
# 2                   -2.4  NaN
# 3                    NaN  NaN
# 4                      -  NaN
# 5                    NaN  NaN
# 6                      -  NaN
# 7                    NaN  NaN
# 8                      -  NaN
# 9                    NaN  NaN
# 10                     -  NaN
# 11                   NaN  NaN
# 12                  +2.2  NaN
# 13               PB/歴代5位  NaN
# 14                 工大新記録  NaN
# 15                     -  NaN
# 16                     -  NaN
# 17   +3.8/PB(6m17(+1.3))  NaN
# 18                   NaN  NaN
# 19                     -  NaN
# 20                   NaN  NaN
# 21                  +1.6  NaN
# 22                   NaN  NaN
# 23                   NaN  NaN
# 24                   NaN  NaN
# 25                  -4.2  NaN
# 26                   NaN  NaN
# 27                   NaN  NaN
# 28                   NaN  NaN
# 29            PB/歴代35位タイ  NaN
# ..                   ...  ...
# 494                    -    -
# 495                    -    -
# 496                    -    -
# 497                    -    -
# 498                    -    -
# 499                    -    -
# 500                    -    -
# 501                    -    -
# 502              PB/歴代4位  NaN
# 503                  NaN  NaN
# 504                  NaN  NaN
# 505                  NaN  NaN
# 506                  NaN  NaN
# 507                  NaN  NaN
# 508                  NaN  NaN
# 509                  NaN  NaN
# 510                  NaN  NaN
# 511                  NaN  NaN
# 512                  NaN  NaN
# 513                  NaN  NaN
# 514                    -  NaN
# 515                  NaN  NaN
# 516                  NaN  NaN
# 517                  NaN  NaN
# 518                  NaN  NaN
# 519                  NaN  NaN
# 520                  NaN  NaN
# 521                  NaN  NaN
# 522                  NaN  NaN
# 523                  NaN  NaN
#
# [524 rows x 6 columns]

# %%
new_dfs = pd.DataFrame(columns=['種目', '組', '選手', '記録', '着順', '風・備考'])

for i in range(len(dfs)):
    line = dfs.iloc[i]['種目']
    temp_df = pd.DataFrame(dfs.iloc[i])
    if re.search('\d', line) or re.search('跳', line) or re.search('投', line) or re.search('マラソン', line):
        temp_df = temp_df.T
    else:
        temp_df = temp_df.shift(1).T
    
    new_dfs = new_dfs.append(temp_df)
    
new_dfs
# Out:
#               種目                     組       選手     記録                   着順  \
# 0           100m                 天野　皓平     10"8     1着                 +2.4
# 1            NaN                 岩井　梨輝     10"9     2着                 +2.4
# 2           200m                 天野　皓平     22"3     1着                 -2.4
# 3            NaN                 西嶋　健人     22"5     3着      -2.4/PB/歴代14位タイ
# 4           400m                 高橋　知也     50"2     2着                    -
# 5            NaN                 中嶋　一貴     51"3     3着           PB/歴代27位タイ
# 6           800m                 箱崎　喜郎   1'59"9     1着                    -
# 7            NaN                 井上　暁人   2'00"3     2着                    -
# 8          1500m                  塩田　匠   4'02"9     1着                    -
# 9            NaN                 箱崎　喜郎   4'03"6     3着             PB/歴代16位
# 10         5000m                  塩田　匠  15'14"3     1着                    -
# 11           NaN                新美　惣一朗  15'36"9     2着                    -
# 12         110mH                 永島　唯哉     14"7     1着                 +2.2
# 13         400mH                 永島　唯哉     56"2     1着              PB/歴代5位
# 14       4×100mR   天野　皓平西嶋　健人永井　生永島　唯哉     41"5     1着                工大新記録
# 15       4×400mR  高橋　知也中嶋　一貴中村　勇太芝江　柾葵   3'26"9     1着                    -
# 16           走高跳                 小河　雅広     1m40     3等                    -
# 17           走幅跳                 石井　裕太     6m30     1等  +3.8/PB(6m17(+1.3))
# 18           NaN                  櫛田　優     5m96     3等                 +3.6
# 19           砲丸投                 福井　義光     8m34     2等                    -
# 20           NaN                 久保　謙太     7m79     4等                    -
# 21       100m OP                 米川　晴義     11"2   1組2着                 +1.6
# 22           NaN                 中村　彩人     11"6   2組2着                 +2.3
# 23           NaN                 下山　達大     11"8   2組4着                 +2.3
# 24           NaN                 白井　陸大     12"1   2組5着                 +2.3
# 25       200m OP                  永井　生     23"4     1着                 -4.2
# 26           NaN                 米川　晴義     23"7     2着                 -4.2
# 27           NaN                 野村　勝洋     24"6     3着                 -4.2
# 28           NaN                 木原　葉子     27"1     6着           -4.2/工大新記録
# 29       400m OP                 中村　勇太     51"9     1着           PB/歴代35位タイ
# ..           ...                   ...      ...    ...                  ...
# 494  女子七種競技100mH                     1    鳥山　夏海    DNS                    -
# 495   女子七種競技200m                     1    鳥山　夏海    DNS                    -
# 496    女子七種競技走高跳                     1    鳥山　夏海    DNS                    -
# 497    女子七種競技砲丸投                     1    鳥山　夏海    DNS                    -
# 498   女子七種競技800m                     1    鳥山　夏海    DNS                    -
# 499    女子七種競技走幅跳                     1    鳥山　夏海    DNS                    -
# 500    女子七種競技やり投                     1    鳥山　夏海    DNS                    -
# 501          NaN                女子七種競技        1  鳥山　夏海                  DNS
# 502         20km                  塩田　匠  1:03'43   227位              PB/歴代4位
# 503          NaN                 多田　駿介  1:07'29   390位              初/歴代18位
# 504          NaN                 杉浦　拓馬  1:08'34   429位             PB/歴代26位
# 505          NaN                 箱崎　喜郎  1:09'15   454位             PB/歴代39位
# 506          NaN                 井上　暁人  1:09'26   458位             PB/歴代40位
# 507          NaN                 山内　岳秋  1:10'04   482位                    -
# 508          NaN                 奈良　悠冬  1:10'47   502位                   PB
# 509          NaN                 久司　駿三  1:11'47   528位                    初
# 510          NaN                 江頭　悠郎  1:12'08   540位                   PB
# 511          NaN                  阿川　陽  1:12'16   541位                    初
# 512          NaN                 小島　俊平  1:15'46   575位                    -
# 513          NaN                田井　裕次郎       DQ      -                    -
# 514         20km                 松井　将器  1:00'58    52位                    -
# 515          NaN                 丸山　蒼太  1:09'32   459位                    -
# 516          NaN                 小林　裕平  1:10'31   495位                    -
# 517          NaN                 武田　直樹  1:11'35   519位                    初
# 518          NaN                 萩原　健太  1:11'54   531位                    初
# 519          NaN                 笠木　浩平  1:12'02   538位                    -
# 520          NaN                田野倉　佑介  1:12'45   551位                    -
# 521          NaN                  辻　航平  1:13'50   562位                    -
# 522          NaN                外山　真矢人  1:16'22   578位                    -
# 523          NaN                 山根　圭太  1:17'27   581位                    -
#
#     風・備考
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# ..   ...
# 494    -
# 495    -
# 496    -
# 497    -
# 498    -
# 499    -
# 500    -
# 501    -
# 502  NaN
# 503  NaN
# 504  NaN
# 505  NaN
# 506  NaN
# 507  NaN
# 508  NaN
# 509  NaN
# 510  NaN
# 511  NaN
# 512  NaN
# 513  NaN
# 514  NaN
# 515  NaN
# 516  NaN
# 517  NaN
# 518  NaN
# 519  NaN
# 520  NaN
# 521  NaN
# 522  NaN
# 523  NaN
#
# [524 rows x 6 columns]

# %%
new_dfs2 = copy.deepcopy(new_dfs)
track = pd.DataFrame(columns=['種目', '組', '選手', '記録', '着順', '風・備考'])
field = pd.DataFrame(columns=['種目', '組', '選手', '記録', '着順', '風・備考'])

status = False
for i in range(len(new_dfs2)):
    discipline = new_dfs2.iloc[i]['種目']
    if isinstance(discipline, str):
        if re.search('投', discipline) or re.search('跳', discipline):
            field = field.append(pd.DataFrame(new_dfs2.iloc[i]).T)
            status = True
            
        else:
            track = track.append(pd.DataFrame(new_dfs2.iloc[i]).T)
            status = False
    
    else:
        if math.isnan(discipline) and status:
            field = field.append(pd.DataFrame(new_dfs2.iloc[i]).T)
            status = True
        
        else:
            track = track.append(pd.DataFrame(new_dfs2.iloc[i]).T)
            status = False

# %%
track['時間'] = [np.nan for i in range(len(track))]
track['分'] = [np.nan for i in range(len(track))]
track['秒']  = [np.nan for i in range(len(track))]
track['秒以下'] = [np.nan for i in range(len(track))]

# %%
track = track.reset_index(drop=True)
field = field.reset_index(drop=True)

# %%
track2 = copy.deepcopy(track)

for i in range(len(track2)):
    line = track2.iloc[i]['記録']

    if re.search(':', line):
        track2['時間'][i] = line.split(':')[0]
        track2['分'][i] = line.split(':')[1].split('\'')[0]
        track2['秒'][i] = line.split(':')[1].split('\'')[1].split('\"')[0]
        
    elif re.search('\'', line):
        track2['分'][i] = line.split('\'')[0]
        track2['秒'][i] = line.split('\'')[1].split('\"')[0]
        if re.search('\"', line):
            track2['秒以下'][i] = line.split('\'')[1].split('\"')[1]
    
    elif re.search('\"', line):
        track2['秒'][i] = line.split('\"')[0]
        track2['秒以下'][i] = line.split('\"')[1]
# Out:
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
track3 = copy.deepcopy(track2)

for i in range(len(track3)):
    discipline = track3.iloc[i]['種目']
    if isinstance(discipline, str):
        temp_dis = discipline
    
    else:
        track3['種目'][i] = temp_dis

track3['区分'] = [np.nan for i in range(len(track3))]
# Out:
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
track4 = copy.deepcopy(track3)

for i in range(len(track4)):
    discipline = track4.iloc[i]['種目']
    
    if re.search(r'H', discipline):
        if len(discipline.split('H')) > 1 and discipline.split('H')[1] != '':
                track4['区分'][i] = discipline.split('H')[1].replace(' ', '')
                track4['種目'][i] = discipline.replace(discipline.split('H')[1], '')
    
    elif re.search(r'C', discipline):
        if len(discipline.split('C')) > 1 and discipline.split('C')[1] != '':
                track4['区分'][i] = discipline.split('C')[1].replace(' ', '')
                track4['種目'][i] = discipline.replace(discipline.split('C')[1], '')

    elif re.search(r'TR', discipline):
        if len(discipline.split('R')) > 1 and discipline.split('m')[1] != '':
                track4['区分'][i] = discipline.split('m')[1].replace(' ', '')
                track4['種目'][i] = discipline.replace(discipline.split('m')[1], '')

    elif re.search(r'mR', discipline):
        if len(discipline.split('R')) > 1 and discipline.split('R')[1] != '':
                track4['区分'][i] = discipline.split('R')[1].replace(' ', '')
                track4['種目'][i] = discipline.replace(discipline.split('R')[1], '')

                
    elif len(discipline.split('m')) > 1 and discipline.split('m')[1] != '':
        track4['区分'][i] = discipline.split('m')[1].replace(' ', '')
        track4['種目'][i] = discipline.replace(discipline.split('m')[1], '')
# Out:
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amano/.pyenv/versions/anaconda3-2.3.0/lib/python3.4/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
track4
# Out:
#               種目                     組                     選手        記録  \
# 0           100m                 天野　皓平                   10"8        1着
# 1           100m                 岩井　梨輝                   10"9        2着
# 2           200m                 天野　皓平                   22"3        1着
# 3           200m                 西嶋　健人                   22"5        3着
# 4           400m                 高橋　知也                   50"2        2着
# 5           400m                 中嶋　一貴                   51"3        3着
# 6           800m                 箱崎　喜郎                 1'59"9        1着
# 7           800m                 井上　暁人                 2'00"3        2着
# 8          1500m                  塩田　匠                 4'02"9        1着
# 9          1500m                 箱崎　喜郎                 4'03"6        3着
# 10         5000m                  塩田　匠                15'14"3        1着
# 11         5000m                新美　惣一朗                15'36"9        2着
# 12         110mH                 永島　唯哉                   14"7        1着
# 13         400mH                 永島　唯哉                   56"2        1着
# 14       4×100mR   天野　皓平西嶋　健人永井　生永島　唯哉                   41"5        1着
# 15       4×400mR  高橋　知也中嶋　一貴中村　勇太芝江　柾葵                 3'26"9        1着
# 16          100m                 米川　晴義                   11"2      1組2着
# 17          100m                 中村　彩人                   11"6      2組2着
# 18          100m                 下山　達大                   11"8      2組4着
# 19          100m                 白井　陸大                   12"1      2組5着
# 20          200m                  永井　生                   23"4        1着
# 21          200m                 米川　晴義                   23"7        2着
# 22          200m                 野村　勝洋                   24"6        3着
# 23          200m                 木原　葉子                   27"1        6着
# 24          400m                 中村　勇太                   51"9        1着
# 25          400m                 細川　和穂                   53"3        2着
# 26          800m                 小林　裕平                 1'59"3        1着
# 27          800m                 松井　将器                 1'59"8        2着
# 28          800m                 笠木　浩平                 2'03"2        3着
# 29          800m                佐々木　亮一                 2'04"9        4着
# ..           ...                   ...                    ...       ...
# 419      女子1500m                     1                 上田　菜々子   5'04"26
# 420            1                  川崎　忍                    DNS         -
# 421      女子1500m                     2                 大谷　菜々子   6'08"48
# 422      女子5000m                     1                 上田　菜々子  18'59"52
# 423    女子4×400mR                     2  鳥山　夏海木原　葉子上田　菜々子丸田　彩佳   4'36"60
# 424  女子七種競技100mH                     1                  鳥山　夏海       DNS
# 425   女子七種競技200m                     1                  鳥山　夏海       DNS
# 426   女子七種競技800m                     1                  鳥山　夏海       DNS
# 427         20km                  塩田　匠                1:03'43      227位
# 428         20km                 多田　駿介                1:07'29      390位
# 429         20km                 杉浦　拓馬                1:08'34      429位
# 430         20km                 箱崎　喜郎                1:09'15      454位
# 431         20km                 井上　暁人                1:09'26      458位
# 432         20km                 山内　岳秋                1:10'04      482位
# 433         20km                 奈良　悠冬                1:10'47      502位
# 434         20km                 久司　駿三                1:11'47      528位
# 435         20km                 江頭　悠郎                1:12'08      540位
# 436         20km                  阿川　陽                1:12'16      541位
# 437         20km                 小島　俊平                1:15'46      575位
# 438         20km                田井　裕次郎                     DQ         -
# 439         20km                 松井　将器                1:00'58       52位
# 440         20km                 丸山　蒼太                1:09'32      459位
# 441         20km                 小林　裕平                1:10'31      495位
# 442         20km                 武田　直樹                1:11'35      519位
# 443         20km                 萩原　健太                1:11'54      531位
# 444         20km                 笠木　浩平                1:12'02      538位
# 445         20km                田野倉　佑介                1:12'45      551位
# 446         20km                  辻　航平                1:13'50      562位
# 447         20km                外山　真矢人                1:16'22      578位
# 448         20km                 山根　圭太                1:17'27      581位
#
#                   着順      風・備考  時間     分     秒   秒以下   区分
# 0               +2.4       NaN NaN   NaN   NaN   NaN  NaN
# 1               +2.4       NaN NaN   NaN   NaN   NaN  NaN
# 2               -2.4       NaN NaN   NaN   NaN   NaN  NaN
# 3    -2.4/PB/歴代14位タイ       NaN NaN   NaN   NaN   NaN  NaN
# 4                  -       NaN NaN   NaN   NaN   NaN  NaN
# 5         PB/歴代27位タイ       NaN NaN   NaN   NaN   NaN  NaN
# 6                  -       NaN NaN   NaN   NaN   NaN  NaN
# 7                  -       NaN NaN   NaN   NaN   NaN  NaN
# 8                  -       NaN NaN   NaN   NaN   NaN  NaN
# 9           PB/歴代16位       NaN NaN   NaN   NaN   NaN  NaN
# 10                 -       NaN NaN   NaN   NaN   NaN  NaN
# 11                 -       NaN NaN   NaN   NaN   NaN  NaN
# 12              +2.2       NaN NaN   NaN   NaN   NaN  NaN
# 13           PB/歴代5位       NaN NaN   NaN   NaN   NaN  NaN
# 14             工大新記録       NaN NaN   NaN   NaN   NaN  NaN
# 15                 -       NaN NaN   NaN   NaN   NaN  NaN
# 16              +1.6       NaN NaN   NaN   NaN   NaN   OP
# 17              +2.3       NaN NaN   NaN   NaN   NaN   OP
# 18              +2.3       NaN NaN   NaN   NaN   NaN   OP
# 19              +2.3       NaN NaN   NaN   NaN   NaN   OP
# 20              -4.2       NaN NaN   NaN   NaN   NaN   OP
# 21              -4.2       NaN NaN   NaN   NaN   NaN   OP
# 22              -4.2       NaN NaN   NaN   NaN   NaN   OP
# 23        -4.2/工大新記録       NaN NaN   NaN   NaN   NaN   OP
# 24        PB/歴代35位タイ       NaN NaN   NaN   NaN   NaN   OP
# 25                 -       NaN NaN   NaN   NaN   NaN   OP
# 26          PB/歴代21位       NaN NaN   NaN   NaN   NaN   OP
# 27                 -       NaN NaN   NaN   NaN   NaN   OP
# 28                 -       NaN NaN   NaN   NaN   NaN   OP
# 29                PB       NaN NaN   NaN   NaN   NaN   OP
# ..               ...       ...  ..   ...   ...   ...  ...
# 419              10着         - NaN   5.0   4.0  26.0   予選
# 420                -       NaN NaN   NaN   NaN   NaN  NaN
# 421              12着      歴代8位 NaN   6.0   8.0  48.0   OP
# 422              15着  PB/工大新記録 NaN  18.0  59.0  52.0   決勝
# 423               8着         - NaN   4.0  36.0  60.0   予選
# 424                -         - NaN   NaN   NaN   NaN  NaN
# 425                -         - NaN   NaN   NaN   NaN  NaN
# 426                -         - NaN   NaN   NaN   NaN  NaN
# 427          PB/歴代4位       NaN NaN   NaN   NaN   NaN  NaN
# 428          初/歴代18位       NaN NaN   NaN   NaN   NaN  NaN
# 429         PB/歴代26位       NaN NaN   NaN   NaN   NaN  NaN
# 430         PB/歴代39位       NaN NaN   NaN   NaN   NaN  NaN
# 431         PB/歴代40位       NaN NaN   NaN   NaN   NaN  NaN
# 432                -       NaN NaN   NaN   NaN   NaN  NaN
# 433               PB       NaN NaN   NaN   NaN   NaN  NaN
# 434                初       NaN NaN   NaN   NaN   NaN  NaN
# 435               PB       NaN NaN   NaN   NaN   NaN  NaN
# 436                初       NaN NaN   NaN   NaN   NaN  NaN
# 437                -       NaN NaN   NaN   NaN   NaN  NaN
# 438                -       NaN NaN   NaN   NaN   NaN  NaN
# 439                -       NaN NaN   NaN   NaN   NaN  NaN
# 440                -       NaN NaN   NaN   NaN   NaN  NaN
# 441                -       NaN NaN   NaN   NaN   NaN  NaN
# 442                初       NaN NaN   NaN   NaN   NaN  NaN
# 443                初       NaN NaN   NaN   NaN   NaN  NaN
# 444                -       NaN NaN   NaN   NaN   NaN  NaN
# 445                -       NaN NaN   NaN   NaN   NaN  NaN
# 446                -       NaN NaN   NaN   NaN   NaN  NaN
# 447                -       NaN NaN   NaN   NaN   NaN  NaN
# 448                -       NaN NaN   NaN   NaN   NaN  NaN
#
# [449 rows x 11 columns]

# %%
track4.to_csv(name + '_track.csv', encoding='shift_jis')

# %%
field2 = copy.deepcopy(field)

for i in range(len(field2)):
    line = field.iloc[i]['記録']

    if re.search('m', line):
        field2['記録'][i] = line.replace('m', '.')
# Out:
#      種目     選手     記録     風        備考
# 0   走高跳  小林　拓己   2.03     -        2等
# 1   NaN  小河　雅広     NM     -         -
# 2   NaN  足達　哲也    DNS     -         -
# 3   円盤投  久保　謙太  27.20     -        4等
# 4   走高跳  小河　雅広   1.70     -         -
# 5   NaN  足達　哲也     NM     -         -
# 6   走高跳  小林　拓己   2.06     -  PB/工大新記録
# 7   NaN  小河　雅広    DNS     -         -
# 8   走幅跳  刈田　浩平    DNS     -         -
# 9   円盤投  久保　謙太  28.12     -  PB/歴代12位
# 10  走幅跳  刈田　浩平   7.09  +0.6        優勝
# 11  走高跳  小林　拓己   2.00     -         -
# 12  走高跳  小林　拓己   2.00     -       NaN
# 13  走高跳  小河　雅広   1.70     -         -
# 14  走幅跳  刈田　浩平   7.41  +3.5         -
# 15  走幅跳  刈田　浩平   6.99  +1.2         -
# 16  走高跳  小林　拓己   2.05     -         -
# 17  NaN  小河　雅広   1.85     -         -
# 18  NaN   櫛田　優   1.75     -        PB
# 19  走高跳  小河　雅広   1.95     -         -
# 20  走高跳  小林　拓己   2.02     -        2等
# 21  走幅跳   櫛田　優   6.15  +1.6        PB
# 22  走幅跳  刈田　浩平    DNS     -         -
# 23  走幅跳  刈田　浩平   7.04  +2.1         -
# 24  走高跳  小林　拓己   2.01     -         -
# 25  NaN   櫛田　優   1.75     -         -
# 26  やり投  福井　義光  42.09     -        PB
# 27  走高跳  小林　拓己   1.95     -         -
# 28  NaN   櫛田　優   1.80     -  PB/歴代11位
# 29  やり投  福井　義光  43.35     -        PB
# 30  走高跳   櫛田　優   1.80     -         -
# 31  NaN  小林　拓己    DNS     -         -

# %%
field3 = copy.deepcopy(field2)

for i in range(len(field3)):
    discipline = field3.iloc[i]['種目']
    if isinstance(discipline, str):
        temp_dis = discipline
    
    else:
        field3['種目'][i] = temp_dis

field3['区分'] = [np.nan for i in range(len(field3))]

# %%
field4 = copy.deepcopy(field3)

for i in range(len(field4)):
    discipline = field4.iloc[i]['種目']
    
    if re.search(r'跳', discipline):
        if len(discipline.split('跳')) > 1 and discipline.split('跳')[1] != '':
                field4['区分'][i] = discipline.split('跳')[1].replace(' ', '')
                field4['種目'][i] = discipline.replace(discipline.split('跳')[1], '')
    
    elif re.search(r'投', discipline):
        if len(discipline.split('投')) > 1 and discipline.split('投')[1] != '':
                field4['区分'][i] = discipline.split('投')[1].replace(' ', '')
                field4['種目'][i] = discipline.replace(discipline.split('投')[1], '')

# %%
field4.to_csv(name + '_field.csv', encoding='shift_jis')
